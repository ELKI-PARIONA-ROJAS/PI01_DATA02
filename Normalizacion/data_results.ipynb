# %%
# importar las librerias y la base de datos

import pandas as pd
import numpy as np

data_results = pd.read_json('F:/PROYECTO_INDIVIDUAL/DATA_ENGINEERING/PI01_DATA02/Datasets/results.json', lines=True)

# %%
data_results.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452           218.3         1
# ...

# %%
data_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24960 entries, 0 to 24959
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   resultId         24960 non-null  int64
#  1   raceId           24960 non-null  int64
#  2   driverId         24960 non-null  int64
#  3   constructorId    24960 non-null  int64
#  4   number           24960 non-null  object
#  5   grid             24960 non-null  int64
#  6   position         24960 non-null  object
#  7   positionText     24960 non-null  object
#  8   positionOrder    24960 non-null  int64
#  9   points           24960 non-null  float64
#  10  laps             24960 non-null  int64
#  11  time             24960 non-null  object
#  12  milliseconds     24960 non-null  object
#  13  fastestLap       24960 non-null  object
#  14  rank             24960 non-null  object
#  15  fastestLapTime   24960 non-null  object
#  16  fastestLapSpeed  24960 non-null  object
# ...

# %%
# renombrar las columnas
data_results.rename(columns={'resultId':'IdResultado','raceId':'IdCarrera','driverId':'IdPiloto','constructorId':'IdConstructor',
'number':'Nro_X','grid':'Parrilla','position':'Posicion','positionText':'PosicionTexto','positionOrder':'PosicionOrden',
'points':'Puntos','laps':'Vueltas','time':'Tiempo','milliseconds':'Duracion(ms)','fastestLap':'VueltaRapida','rank':'Rango',
'fastestLapTime':'TiempoVueltaRapida','fastestLapSpeed':'VelocidadVueltaRapida','statusId':'IdEstado'}, inplace=True)

# %%
# Eliminar los duplicados en la columna de IdResultado
data_results.drop_duplicates(subset='IdResultado', keep='first', inplace=True)

# %%
# establecer a driverId como indice
data_results = data_results.set_index('IdResultado')

# %%
# contar cuantos valores de tipo '\\N' hay en cada columna
data_results.apply(lambda x: sum(x=='\\N'), axis=0)
# Out:
# IdCarrera                    0
# IdPiloto                     0
# IdConstructor                0
# Nro_X                        6
# Parrilla                     0
# Posicion                 10735
# PosicionTexto                0
# PosicionOrden                0
# Puntos                       0
# Vueltas                      0
# Tiempo                   18368
# Duracion(ms)             18369
# VueltaRapida             18410
# Rango                    18249
# TiempoVueltaRapida       18410
# VelocidadVueltaRapida    18410
# IdEstado                     0
# dtype: int64

# %%
# Reemplazar los valores '\\N' y los vacios por valores nulos
data_results = data_results.replace('\\N', np.nan)
data_results = data_results.replace('', np.nan)

# Reemplazar los valores '\\N' y nulos por valores vacios
# data_results = data_results.replace('\\N', '')
# data_results = data_results.replace(np.nan, '')

# %%
# Extraer en otra dataframe los valores nulos los que no tienen nulos en la columna 'Duracion(ms)'
results_notnull = data_results[data_results['Duracion(ms)'].notnull()]

# %%
results_notnull.head()
# Out:
#              IdCarrera  IdPiloto  IdConstructor  Nro_X  Parrilla  Posicion  \
# IdResultado
# 1                   18         1              1   22.0         1       1.0
# 2                   18         2              2    3.0         5       2.0
# 3                   18         3              3    7.0         7       3.0
# 4                   18         4              4    5.0        11       4.0
# 5                   18         5              1   23.0         3       5.0
#
#             PosicionTexto  PosicionOrden  Puntos  Vueltas       Tiempo  \
# IdResultado
# 1                       1              1    10.0       58  1:34:50.616
# 2                       2              2     8.0       58       +5.478
# 3                       3              3     6.0       58       +8.163
# 4                       4              4     5.0       58      +17.181
# 5                       5              5     4.0       58      +18.014
#
# ...

# %%
data_results.head()
# Out:
#              IdCarrera  IdPiloto  IdConstructor  Nro_X  Parrilla  Posicion  \
# IdResultado
# 1                   18         1              1   22.0         1       1.0
# 2                   18         2              2    3.0         5       2.0
# 3                   18         3              3    7.0         7       3.0
# 4                   18         4              4    5.0        11       4.0
# 5                   18         5              1   23.0         3       5.0
#
#             PosicionTexto  PosicionOrden  Puntos  Vueltas       Tiempo  \
# IdResultado
# 1                       1              1    10.0       58  1:34:50.616
# 2                       2              2     8.0       58       +5.478
# 3                       3              3     6.0       58       +8.163
# 4                       4              4     5.0       58      +17.181
# 5                       5              5     4.0       58      +18.014
#
# ...

# %%
data_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24960 entries, 1 to 24965
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   IdCarrera              24960 non-null  int64
#  1   IdPiloto               24960 non-null  int64
#  2   IdConstructor          24960 non-null  int64
#  3   Nro_X                  24954 non-null  float64
#  4   Parrilla               24960 non-null  int64
#  5   Posicion               14225 non-null  float64
#  6   PosicionTexto          24960 non-null  object
#  7   PosicionOrden          24960 non-null  int64
#  8   Puntos                 24960 non-null  float64
#  9   Vueltas                24960 non-null  int64
#  10  Tiempo                 6592 non-null   object
#  11  Duracion(ms)           6591 non-null   float64
#  12  VueltaRapida           6550 non-null   float64
#  13  Rango                  6711 non-null   float64
# ...

# %%
# exportar la data a un archivo csv
data_results.to_csv('F:/PROYECTO_INDIVIDUAL/DATA_ENGINEERING/PI01_DATA02/DATA_FINAL/results.csv')

# %%
# exportar la data a un archivo csv
results_notnull.to_csv('F:/PROYECTO_INDIVIDUAL/DATA_ENGINEERING/PI01_DATA02/DATA_FINAL/results_notnull.csv')
